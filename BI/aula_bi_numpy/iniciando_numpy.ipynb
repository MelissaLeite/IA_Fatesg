# %%
import numpy as np

# %%
vet = np.array([1, 2, 3, 6, 8, 9, 10, 11, 13, 14, 15, 101, 15, 10, 13, 12, 3, 1, 102])
vet
# Out:
# array([  1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         10,  13,  12,   3,   1, 102])

# %%
type(vet) #verificar o tipo
# Out:
# numpy.ndarray

# %%
vet2 = np.array([1, 2, 3, 4, 5])
vet2.cumsum() #soma dos anteriores com o próximo (espécie de fibonacci)
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
vet[4] #printando o valor da lista com o tipo
# Out:
# np.int64(8)

# %%
print(vet[4]) #printando o valor da lista sem dizer o tipo
# Out:
# 8

# %%
vet[0] = -1 #alterando o valor do primeiro índice da lista
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         10,  13,  12,   3,   1, 102])

# %%
vet = np.append(vet,105) #acrescentar o número na última posição
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         10,  13,  12,   3,   1, 102, 105])

# %%
vet = vet[:-1] #eu quero todos os numeros da lista, exceto o último
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         10,  13,  12,   3,   1, 102])

# %%
vet = np.delete(vet,-3) #deletando a terceira posição de trás pra frente
vet
# Out:
# array([ -1,   2,   3,   6,   8,   9,  10,  11,  13,  14,  15, 101,  15,
#         10,  13,  12,   1, 102])

# %%
vet.shape #diz a qtd de elementos que tem dentro da lista
# Out:
# (18,)

# %%
vetor = np.array ([[0, -5], [11, 300]]) #criando matriz (lista de lista)
vetor
# Out:
# array([[  0,  -5],
#        [ 11, 300]])

# %%
vetor.shape
# Out:
# (2, 2)

# %%
vetor3x2 = np.array ([[1, 2], [3, 4], [5, 6]])
vetor3x2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
vetor3x2.shape
# Out:
# (3, 2)

# %%
vetor2x3 = np.array ([[1, 2, 3], [4, 5, 6]])
vetor2x3
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
vetor2x3.shape
# Out:
# (2, 3)

# %%
y = np.arange(2, 200, 4) #o próprio numpy cria a matriz, mas vc define: qual o primeiro nº, qual o último nº e de quanto em quanto será acrescentado
y
# Out:
# array([  2,   6,  10,  14,  18,  22,  26,  30,  34,  38,  42,  46,  50,
#         54,  58,  62,  66,  70,  74,  78,  82,  86,  90,  94,  98, 102,
#        106, 110, 114, 118, 122, 126, 130, 134, 138, 142, 146, 150, 154,
#        158, 162, 166, 170, 174, 178, 182, 186, 190, 194, 198])

# %%
#unique: remove repetições
unicos_vet = np.unique(vet)
unicos_vet
# Out:
# array([ -1,   1,   2,   3,   6,   8,   9,  10,  11,  12,  13,  14,  15,
#        101, 102])

# %%
idades = np.array ([44, 45, 23, 23, 28, 19, 20, 19, 17, 51, 29 , 28, 31, 32])
mediaIA2.mean() #já dá a média
# Out:
# np.float64(29.214285714285715)

# %%
x = round(idades.mean(),2) #arredondando a média para duas casas decimais
x
# Out:
# np.float64(29.21)

# %%
j = np.unique(idades) #removendo as repetições das idades
j
# Out:
# array([17, 19, 20, 23, 28, 29, 31, 32, 44, 45, 51])

# %%
j.mean()
# Out:
# np.float64(30.818181818181817)

# %%
j = round(idades.mean(),2)
j
# Out:
# np.float64(29.21)
